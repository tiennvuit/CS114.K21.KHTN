# %% [markdown]
# <h1><center><font color=blue>MÔN HỌC: MÁY HỌC</font></center</h1>
# <h1><center>LỚP: CS114.K21.KHTN</center</h1>
#
# # <center>ĐỒ ÁN CUỐI KỲ</center>
#
# # <center><font color=blue>BÀI TOÁN: PHÁT HIỆN KHUÔN MẶT GIẢ MẠO QUA ĐIỆN THOẠI DI ĐỘNG</font></center>
#
# # <center><font color=blue>Tên tiếng anh: Anti-Spoofing face via mobile device</font></center>
#
#
#
#
#
#
# <font size=3><center>Năm học: 2019-2020</center></fontsize>

# %% [markdown]
# *Thông tin học viên*
#
# - Tên: Nguyễn Văn Tiến.
#
# - Lớp:  CS114.KHTN.K21.
#
# - Năm học 2019-2020.
#
# *Thông tin đồ án*
# - Dữ liệu thu thập tại [đây](https://drive.google.com/drive/folders/1P3uO1lQrTTdc8f0cuSVmOYjmJae09Imt?usp=sharing)
#
# - Repository trên Github: https://github.com/tiennvuit/CS114.K21.KHTN/tree/master/Capstone_FakeFaceDetection
#
# - Video demo:
#     + <strike>[Demo 1](). </strike>
#     + [Fake Face detection (CS114 K21.KHTN)](https://youtu.be/pVgZer1h0qA).
# - <strike>File báo cáo đồ án (định dạng pptx).</strike>
#
# *Các chứng chỉ online liên quan môn học*
#
# - [Convolution Neural Network](https://coursera.org/share/d1beb35fd13a6900d277aa47f438c5b3)
#
# - [Neural Networks and Deep Learning](https://coursera.org/share/9dd8ead6af804d2fcb3b852795f704dd)
#
# - [Improving Deep Neural Networks:
# Hyperparameter tuning, Regularization and
# Optimization](https://coursera.org/share/133b646474c454bedaa3e44d19cf79b0)
#
# - [Structuring Machine Learning Projects](https://coursera.org/share/0ffcc99b58489f839d8c3bbc81351a76)
#
# - [Sequence Models](https://coursera.org/share/421500457f0c60661c8de9720830378b)

# %% [markdown]
# ## <font color=blue> Mô tả bài toán
#
#
# ---

# %% [markdown]
# - Phát biểu bài toán: Phát hiện khuôn mặt trong ảnh /video có phải khuôn mặt giả mạo hay không.
#
# - Input: một ảnh/đoạn video/stream video.
#
# - Output: khuôn mặt trong ảnh/video có phải là khuôn mặt giả mạo (1 hoặc 0) hay không.

# %% [markdown]
# ## <font color=blue>Tại sao cần phát hiện khuôn mặt giả mạo</font>
#
#
# ---

# %% [markdown]
# - Các hệ thống nhận diện khuôn mặt được áp dụng trong các ứng dụng điểm danh, thanh toán nhằm xác định danh tính của con người thông khuôn mặt của họ. Hệ thống nhận dạng khuôn mặt có thể bị đánh lừa bằng cách sử dụng bức ảnh chân dung của một người đã được chụp lại bằng điện thoại di động hay ảnh được in ra. Vì vậy chúng ta cần phải phân loại xem khuôn mặt được đặt trước camera có phải là khuôn mặt giả mạo hay không để đảm bảo tính an toàn của hệ thống.

# %% [markdown]
# ## <font color=blue>Mục tiêu đồ án</blue>
#
# ---

# %% [markdown]
# - Tìm hiểu bài toán Phát hiện khuôn mặt giả mạo thông qua ảnh lưu trong điện thoại, ảnh được in.
#
# - Hiện thực hóa quá trình làm một bài toán máy học với các bước.
#
# - <strike>Xây dựng demo ứng dụng phát hiện khuôn mặt giả mạo.</strike>

# %% [markdown]
# ## <font color=blue>Mô tả về bộ dữ liệu<font>
#
#
# ---

# %% [markdown]
# ### Cách xây dựng dữ liệu

# %% [markdown]
# - Dữ liệu được thu thập gồm có hai lớp là ảnh chứa khuôn mặt giả thật (0 - Real) và khuôn mặt giả mạo (1 - Fake).
#
# - Dữ liệu ảnh chứa khuông mặt thật được rút trích từ video selfie ghi lại khuôn mặt thật của một/nhiều đối tượng. Dữ liệu khuôn mặt giả mạo được rút trích từ:
#     + Video ghi lại khuôn mặt giả mạo của một/nhiều đối tượng.
#     + <strike>Ảnh chụp khuôn mặt được in ra giấy.</strike>

# %% [markdown]
# ### Quy trình xây dựng bộ dữ liệu

# %% [markdown]
# #### Xây dựng bộ dữ liệu khuôn mặt thật

# %% [markdown]
# - Bước 1: Sử dụng điện thoại di động ghi lại 30s selfie bản thân khi đang di chuyển (nhằm xây dựng dữ liệu cho lớp dữ liệu khuôn mặt thật).
#
# - Bước 2: Sử dụng thuật toán face detection được hỗ trợ trong thư viện OpenCV để cắt các vùng chứa khuôn mặt trong mỗi fame của 2 video ghi được và lưu tương ứng vào hai thư mục là real.
#
# - Bước 3: Lặp lại bước 1, 2 đối với người khác.

# %% [markdown]
# #### Xây dựng bộ dữ liệu khuôn mặt giả mạo từ dữ liệu thật

# %% [markdown]
# - Bước 1: Sử dụng điện thoại di động quay đoạn video ghi khuôn mặt thật ở trên(nhằm xây dựng dữ liệu cho lớp khuôn mặt giả mạo).
#
# - Bước 2: Sử dụng thuật toán face detection được hỗ trợ trong thư viện OpenCV để cắt các vùng chứa khuôn mặt trong mỗi fame của 2 video ghi được và lưu tương ứng vào hai thư mục là fake.
#
# - Bước 3 (giấy in màu): Lặp lại bước 1,2 đối với video khác.

# %% [markdown]
# ***Một số nhận xét:***
#
# - Bộ dữ liệu chưa đa dạng về độ tuổi, giới tính, hình dạng của khuôn mặt người chính vì thế không có tính tổng quát.

# %% [markdown]
# ### Tiền xử lý dữ liệu

# %% [markdown]
# Ảnh khuôn mặt được cắt từ video được tiền xử lý qua một các bước bên dưới:
#
# - Loại bỏ các ảnh mờ, ảnh không nhìn rõ khuôn mặt bằng việc cho các ảnh đi qua bộ phát hiện mờ (Blur detection).
#
#     Phương pháp tham khảo tại: [Blur detection with OpenCV](https://www.pyimagesearch.com/2015/09/07/blur-detection-with-opencv/)
#
#
# - Kiểm tra các bức ảnh đã được lọc ở bước trên (kiểm tra bằng tay) xem có chứa khuôn mặt hay không, nếu không chứa thì xóa.

# %% [markdown]
# ### Một số thông tin thống kê về tập dữ liệu

# %% [markdown]
# *Ngày 11/7/2020*
#
# - Số lượng dữ liệu: 1916
#
# - Số lượng dữ liệu của mỗi lớp:
#     + Fake: 1115
#     + Real: 806
#
# - Số lượng video thu thập: 6 real và 6 fake tương ứng.
#
#
# *Ngày 10/7/2020*
#
# - Số lượng dữ liệu: 1479
#
# - Số lượng dữ liệu của mỗi lớp:
#     + Fake: 1030
#     + Real: 449
#
# - Số lượng video thu thập: 3 real và 3 fake tương ứng.
#
#
# *Ngày 7/7/2020*
# - Số lượng dữ liệu: 300
#
# - Số lượng dữ liệu của mỗi lớp:
#     + Fake: 557
#     + Real: 184
#
# - Số lượng video thu thập: 1 real và 1 fake tương ứng.

# %% [markdown]
# ## Các phương pháp tiếp cận bài toán
#
# ---

# %% [markdown]
# Qua việc khảo sát bài báo khoa học [Fake Face Detection Methods: Can They Be Generalized](https://www.researchgate.net/publication/327350438_Fake_Face_Detection_Methods_Can_They_Be_Generalized), hiện tại chúng ta có hai hướng tiếp cận bài toán đó là sử dụng đặc trưng do chuyên gia đề xuất (hand-crafted feature) và hướng tiếp cận dựa trên đặc trưng học sâu (deep learning).
#
# Trong phần tiếp theo, em sử dụng 2 phương pháp tiếp cận là dùng đặc trưng rút trích bằng phương pháp Local Binary Pattern và đặc trưng dựa trên Deep Learning được rút trích từ các kiến trúc mạng dựa trên Convolutional Neural Network (CNNs).

# %% [markdown]
# Qua tìm hiểu em biết được: Các phương pháp cho bài toán phát hiện khuôn mặt giả mạo (liveness detection hay anti fake face spooting), gồm có:
#
# 1. Texture analysis: sử dụng đặc trưng Local Binary Pattern (LBPs) để rút trích đặc trưng từ vùng chứa khuôn mặt và sử dụng bộ phân lớp SVM cho giai đoạn phân loại thật hay giả mạo.
#
# 2. Frequency ananlysis.
#
# 3. Variable focusing analysis.
#
# 4. Heuristic-based algorithms(thuật toán dựa trên heuristic): gồm có phát hiện sự chuyển động của mắt, môi, chớp mắt. Các thuật toán theo dõi sự chuyển động của mắt và chớp mắt để đảm bảo người dùng không sử dụng ảnh của người khác (vì ảnh không thể nhấp nháy mắt và chuyển động môi).
#
# 5. Optical flow algorithms.
#
# 6. 3D face shape.
#
# 7. Kết hợp các thuật toán trên.
#
#
# Trong phạm vi đề tài, em xem bài toán này là bài toán phân lớp nhị phân (binary classification) với hai lớp là <strong><i>real</i></strong> và <strong><i>fake</i></strong>.  và đánh giá mô hình dựa trên các độ đo là: *accuracy*, *precision*, *recall*.

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/School_UIT/Semester IV/[CS114] Machine Learning/Working/CS114.K21.KHTN/Capstone_FakeFaceDetection
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive/My Drive/School_UIT/Semester IV/[CS114] Machine Learning/Working/CS114.K21.KHTN/Capstone_FakeFaceDetection

# %% [markdown]
# ## <center><font color=blue>Phương pháp rút trích đặt trưng Local Binary Patterns (LBPs) </font></center>

# %% [markdown]
# ### 1. Tổng quan về Hand-crafted feature
#
# Tham khảo tại: [Quick Note 2: Transfer Learning cho bài toán phân loại ảnh
# ](https://machinelearningcoban.com/2017/07/02/tl/)

# %% [markdown]
# Khi giải quyết một bài toán máy học, ta phải trải qua các bước để đạt được mô hình sau cùng cho ta độ tốt có thể chập nhận được. Trong quy trình máy học, hai giai đoạn Feature engineering (chế tác đặc trưng) và Training model (huấn luyện mô hình) được xử lý riêng biệt. Các phương pháp sử dụng để chế tác đặc trưng từ ảnh đó là:
#
# - [SIFT](https://docs.opencv.org/3.1.0/da/df5/tutorial_py_sift_intro.html)(Scale Invariant Feature Transform).
#
# - [SURF](https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_feature2d/py_surf_intro/py_surf_intro.html) (Speeded-Up Robust Features).
#
# - [HOG](https://www.learnopencv.com/histogram-of-oriented-gradients/) (Histogram of Oriented Gradients).
#
# - [LBP](https://www.pyimagesearch.com/2015/12/07/local-binary-patterns-with-python-opencv/) (Local Binary Pattern).
#
# Các phương pháp chế tác đặc trưng được nêu bên trên được gọi là đặc trưng chế tác một cách thủ công vì các đặc trưng này dựa trên các quan sát về đặc tính riêng của ảnh (còn gọi là đặc trưng do chuyên gia đề xuất). Sau quá trình rút trích đặt trưng, ta đi đến giai đoạn huấn luyện bộ phân lớp (training classifier). Các mô hình phân lớp được dùng đó là:
#
# - Multi-class SVM (Suport Vector Machine).
#
# - Random Forest.
#
# - Softmax Regression.

# %% [markdown]
# Với bài toán phân loại khuôn mặt giả mạo (chủ yếu giả mạo qua hình ảnh trong điện thoại) qua cách tiếp cận dựa trên đặc trưng do chuyên gia đề xuất cho bài toán liên quan tới khuôn mặt người, em sẽ tìm hiểu về phương pháp rút trích đặc trựng Local Binary Patterns (LBPs).

# %% [markdown]
# ### 2. Phương pháp rút trích đặc trưng Local Binary Pattern ?

# %% [markdown]
# Tham khảo: [Local Binary Pattern](https://www.pyimagesearch.com/2015/12/07/local-binary-patterns-with-python-opencv/)

# %% [markdown]
# Phương pháp Local Binary Patterns là một phương pháp dùng để rút trích các đặc trưng bên trong hình ảnh dựa trên các phép toán trên các pixel lân cận (local operation). Input là một ảnh, output là một vector đặc trựng.
#
# Dưới đây là quá trình tính toán của phương pháp LBPs.
#
#
# - Bước 1: Chuyển hình ảnh đầu vào về ảnh thang độ xám (grayscale).
#
# - Bước 2: Với mỗi pixel tại vị trí $(i,j)$ ta thực hiện các bước:
#
#     + Bước 3: Chọn vùng lân cận pixel đó với kích thước là $r$, với tâm là pixel hiện tại.
#
#     + Bước 4: Tính giá trị LBPs của pixel đó, outut của bước này là một mảng hai chiều có kích thước $r \times r$.
#
#     + Bước 5: Duỗi mảng hai chiều ở bước trên thành một chuỗi nhị phân (theo chiều kim đồng hồ hoặc ngược chiều kim).
#
#     + Bước 6: Chuyển giá trị chuỗi nhị phân về hệ cơ số 10 và lưu vào một ma trận M tại vị trí $(i, j)$ giá trị vừa lấy được.
#
# - Bước 7: Duỗi (flatting) ma trận thu được để tạo ra vector đặc trưng LBPs.

# %% [markdown]
# ### 3. Tiến hành rút trích đặc trưng dựa bằng phương pháp Local Binary Patterns.

# %%
# import the necessary packages
from skimage import feature
from imutils import paths
import numpy as np
import matplotlib.pyplot as plt
import pickle
import cv2
import os
import datetime

# %% [markdown]
# Ví dụ rút trích đặt trưng LBPs một ảnh

# %%
TEST_PATH = 'images/test_lbp.png'
test_image = cv2.imread(TEST_PATH)

numPoints = 24
radius = 8
gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
lbp = feature.local_binary_pattern(gray, numPoints, radius, method="uniform")

# Plot the origin image and local binary pattern of image
fig = plt.figure(figsize=(9, 6))
ax = []
# create subplot and append to ax
fig.add_subplot(1, 3, 1)
plt.imshow(test_image)
fig.add_subplot(1, 3, 2)
plt.imshow(lbp)
fig.add_subplot(1, 3, 3)
hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, numPoints + 3), range=(0, numPoints + 2))
hist = hist.astype("float")

hist /= (hist.sum() + 1e-7)
plt.bar(np.arange(0, len(hist)), hist)

plt.show()

# %% [markdown]
# Rút trích đặc trưng cho từ tập dữ liệu ảnh

# %%
class LocalBinaryPatterns:
    def __init__(self, numPoints, radius):
        # store the number of points and radius
        self.numPoints = numPoints
        self.radius = radius
    def describe(self, image, eps=1e-7):
        # compute the Local Binary Pattern representation
        # of the image, and then use the LBP representation
        # to build the histogram of patterns
        lbp = feature.local_binary_pattern(image, self.numPoints,
                                           self.radius, method="uniform")
        (hist, _) = np.histogram(lbp.ravel(),
                                 bins=np.arange(0, self.numPoints + 3),
                                 range=(0, self.numPoints + 2))
        # normalize the histogram
        hist = hist.astype("float")
        hist /= (hist.sum() + eps)
        # return the histogram of Local Binary Patterns
        return hist

# %%
desc = LocalBinaryPatterns(numPoints=24, radius=8)

# %%
def load_dataset(data_path):
    data = []
    labels = []
    # loop over the training images
    for imagePath in paths.list_images(data_path):
        # load the image, convert it to grayscale, and describe it
        image = cv2.imread(imagePath)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        hist = desc.describe(gray)
        # extract the label from the image path, then update the
        # label and data lists
        labels.append(imagePath.split(os.path.sep)[-3])
        data.append(hist)
    return data, labels

# %%
PATH_DATA = './dataset'
print("[INFO] loading images and extracting features")
data, labels = load_dataset(data_path=PATH_DATA)
# Out:
# [INFO] loading images and extracting features

# %% [markdown]
# ### Phân chia dữ liệu huấn luyện

# %%
from sklearn.model_selection import train_test_split
TEST_SIZE = 0.2
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=TEST_SIZE, random_state=42)

# %% [markdown]
# ### Thử nghiệm các bộ phân lớp

# %% [markdown]
# Vì chưa rõ được hiệu quả của các mô hình đối với cách rút trích đặc này cũng như là trên tập dữ liệu thu thập được nên em huấn luyện các bộ phân lớp trên cùng một tập dữ liệu trên tập dữ liệu huấn luyện và đánh giá trên tập dữ liệu kiểm thử được tách ra từ tập dữ liệu thu thập được.
#
# Tuy nhiên, cần phải đánh giá mô hình trên tập dữ liệu unseen (được thu thập riêng biệt) để kiểm tra khả năng tổng quát của mô hình trong thực tế.
#
# Dưới đây là các bộ phân lớp em thử nghiệm:
#
# - Logistic Regression.
#
# - K-nestest Neighbors (kNN).
#
# - Random Forest.
#
# - Decision Tree.
#
# - Naive Bayes.
#
# - Support Vector Machine (SVM).
#
# - Multilayer Perceptron Learnings (MLPs).

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# The measure of classification problem
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
# Định nghĩa các bộ phân lớp

logistic_model = LogisticRegression()
kNN_model = KNeighborsClassifier(n_neighbors=2)
randomForest_model = RandomForestClassifier(max_depth=2, random_state=0)
decisionTree_model = tree.DecisionTreeClassifier()
bayes_model = GaussianNB()
svm_model = make_pipeline(StandardScaler(), SVC(gamma='auto'))
neuronNet_model = MLPClassifier(solver='lbfgs', alpha=1e-5,
                                hidden_layer_sizes=(64, 32, 32, 64, 2),
                                random_state=1)

# %% [markdown]
# #### Mô hình logistic regression
#
# Tham khảo: [sklearn.linear_model.LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %%
print("[INFO] Logistic Regression model...")
logistic_model.fit(trainX, trainY)
print("- The accuracy of model on training set: {}".format(logistic_model.score(trainX, trainY)))
y_pred = logistic_model.predict(testX)
print("- The accuary of model on test set: {}".format(accuracy_score(y_true=testY, y_pred=y_pred)))
print("- The confusion matrix of model on test set: \n{}".format(classification_report(y_true=testY, y_pred=y_pred)))

# %%
# save the model to disk
filename = 'saved_model/hand_crafted_model/logistic_model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M")
pickle.dump(logistic_model, open(filename, 'wb'))

# %% [markdown]
# #### Mô hình k-nestest Neighbors
#
# Tham khảo: [sklearn.neighbors.KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %%
print("[INFO] k-nestest Neighbors model...")
kNN_model.fit(trainX, trainY)
print("- The accuracy of model on training set: {}".format(kNN_model.score(trainX, trainY)))
y_pred = kNN_model.predict(testX)
print("- The accuary of model on test set: {}".format(accuracy_score(y_true=testY, y_pred=y_pred)))
print("- The confusion matrix of model on test set: \n{}".format(classification_report(y_true=testY, y_pred=y_pred)))

# %%
# save the model to disk
filename = 'saved_model/hand_crafted_model/kNN_model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M")
pickle.dump(logistic_model, open(filename, 'wb'))

# %% [markdown]
# #### Mô hình Random Forest
#
# Tham khảo: [3.2.4.3.1. sklearn.ensemble.RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %%
print("[INFO] Random Forest model...")
randomForest_model.fit(trainX, trainY)
print("- The accuracy of model on training set: {}".format(randomForest_model.score(trainX, trainY)))
y_pred = randomForest_model.predict(testX)
print("- The accuary of model on test set: {}".format(accuracy_score(y_true=testY, y_pred=y_pred)))
print("- The confusion matrix of model on test set: \n{}".format(classification_report(y_true=testY, y_pred=y_pred)))

# %%
# save the model to disk
filename = 'saved_model/hand_crafted_model/randomForest_model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M")
pickle.dump(logistic_model, open(filename, 'wb'))

# %% [markdown]
# #### Mô hình Decision tree
#
# Tham khảo: [1.10. Decision Trees](https://scikit-learn.org/stable/modules/tree.html)

# %%
print("[INFO] Decision Tree...")
decisionTree_model.fit(trainX, trainY)
print("- The accuracy of model on training set: {}".format(decisionTree_model.score(trainX, trainY)))
y_pred = decisionTree_model.predict(testX)
print("- The accuary of model on test set: {}".format(accuracy_score(y_true=testY, y_pred=y_pred)))
print("- The confusion matrix of model on test set: \n{}".format(classification_report(y_true=testY, y_pred=y_pred)))

# %%
# save the model to disk
filename = 'saved_model/hand_crafted_model/decisionTree_model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M")
pickle.dump(logistic_model, open(filename, 'wb'))

# %% [markdown]
# #### Mô hình Naive Bayes
#
# Tham khảo: [1.9. Naive Bayes](https://scikit-learn.org/stable/modules/naive_bayes.html)

# %%
print("[INFO] Naive Bayes model...")
bayes_model.fit(trainX, trainY)
print("- The accuracy of model on training set: {}".format(bayes_model.score(trainX, trainY)))
y_pred = bayes_model.predict(testX)
print("- The accuary of model on test set: {}".format(accuracy_score(y_true=testY, y_pred=y_pred)))
print("- The confusion matrix of model on test set: \n{}".format(classification_report(y_true=testY, y_pred=y_pred)))

# %%
# save the model to disk
filename = 'saved_model/hand_crafted_model/bayes_model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M")
pickle.dump(logistic_model, open(filename, 'wb'))

# %% [markdown]
# #### Mô hình SVM
#
# Tham khảo: [sklearn.svm.SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)

# %%
print("[INFO] SVM model...")
svm_model.fit(trainX, trainY)
print("- The accuracy of model on training set: {}".format(svm_model.score(trainX, trainY)))
y_pred = svm_model.predict(testX)
print("- The accuary of model on test set: {}".format(accuracy_score(y_true=testY, y_pred=y_pred)))
print("- The confusion matrix of model on test set: \n{}".format(classification_report(y_true=testY, y_pred=y_pred)))

# %%
# save the model to disk
filename = 'saved_model/hand_crafted_model/svm_model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M")
pickle.dump(logistic_model, open(filename, 'wb'))

# %% [markdown]
# #### Mô hình Neuron network
#
# Tham khảo: [sklearn.neural_network.MLPClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier)

# %%
print("[INFO] Neuron Network model...")
neuronNet_model.fit(trainX, trainY)
print("- The accuracy of model on training set: {}".format(neuronNet_model.score(trainX, trainY)))
y_pred = neuronNet_model.predict(testX)
print("- The accuary of model on test set: {}".format(accuracy_score(y_true=testY, y_pred=y_pred)))
print("- The confusion matrix of model on test set: \n{}".format(classification_report(y_true=testY, y_pred=y_pred)))

# %%
# save the model to disk
filename = 'saved_model/hand_crafted_model/neuronnet_model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M")
pickle.dump(logistic_model, open(filename, 'wb'))

# %% [markdown]
# ### <strike>Đánh giá mô hình trên tập dữ liệu unseen</strike>

# %% [markdown]
# ## Phương pháp dựa trên deep learning
#
#
# ---

# %%
# Import các thư viện cần dùng
from classifier.livenessnet import LivenessNet
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from imutils import paths
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

import argparse
import pickle
import cv2
import os
import random
import datetime
from utils import plot_progress
# %matplotlib inline

# %% [markdown]
# ### 1. Load dữ liệu

# %%
# Define the load_dataset function

def load_dataset(dataset_path: str):
    # grab the list of images in our dataset directory, then initialize
    # the list of data (i.e., images) and class images
    print("[INFO] loading images...")
    imagePaths = list(paths.list_images(dataset_path))
    data = []
    labels = []

    # loop over all image paths
    for imagePath in imagePaths:
        # extract the class label from the filename, load the image and
        # resize it to be a fixed 32x32 pixels, ignoring aspect ratio
        label = imagePath.split(os.path.sep)[-3]
        image = cv2.imread(imagePath)
        image = cv2.resize(image, (64, 64))

        # update the data and labels lists, respectively
        data.append(image)
        labels.append(label)
        
    # encode the labels (which are currently strings) as integers and then
    # one-hot encode them
    le = LabelEncoder()
    labels = le.fit_transform(labels)
    labels = to_categorical(labels, 2)

    return data, labels, le

# %%
PATH_DATASET = "./dataset"
data, labels, le = load_dataset(PATH_DATASET)

# %% [markdown]
# Xem thông tin của tập dữ liệu

# %%
print("[INFO] The dataset...")
print("- The size of dataset {}".format(len(labels)))
fake_indices = [index for index in range(len(data)) if np.argmax(labels[index]) == 0] 
print("- The number of fake (0) face image is {}".format(len(fake_indices)))
print("- The number of real (1) face image is {}".format(len(labels) - len(fake_indices)))

# %%
def plot_images(data, indices, column: int):
    fig = plt.figure(figsize=(9, 6))
    row = len(indices) // column
    ax = []
    for i in range(column*row):
        # create subplot and append to ax
        ax.append(fig.add_subplot(row, column, i+1))
        plt.imshow(data[indices[i]])
        
    plt.show()

# %% [markdown]
# Visualize 20 ảnh chứa khuôn mặt <b>giả mạo</b> trong tập dữ liệu.

# %%
indices = list(set(np.random.choice(len(fake_indices), 20)))
print("Fake face....")
plot_images(data, indices=indices, column=5)

# %% [markdown]
# Visualize 20 ảnh chứa khuôn mặt <b>thật</b> trong tập dữ liệu

# %%
real_indices = [index for index in range(len(data)) if np.argmax(labels[index]) == 1]
print("Real face...")
indices = list(set(np.random.choice(len(real_indices), 20)))
plot_images(data, indices=indices, column=5)

# %% [markdown]
# ### 2. Chia dữ liệu huấn luyện

# %%
# convert the data into a NumPy array, then preprocess it by scaling
# all pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0

# %%
TEST_SIZE = 0.2
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=TEST_SIZE, random_state=42)

# %% [markdown]
# ### 3. Xây dựng mô hình

# %% [markdown]
# Sử dụng các kiến trúc mạng dựa trên CNNs (Convolutional Neuron Network).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras import backend as K

# %%
height, width, depth = data[0].shape

# %%
model = Sequential()
inputShape = (height, width, depth)
chanDim = -1

# if we are using "channels first", update the input shape
# and channels dimension
if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
    chanDim = 1

# first CONV => RELU => CONV => RELU => POOL layer set
model.add(Conv2D(16, (3, 3), padding="same",
    input_shape=inputShape))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(16, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# second CONV => RELU => CONV => RELU => POOL layer set
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# first (and only) set of FC => RELU layers
model.add(Flatten())
model.add(Dense(64))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# softmax classifier
model.add(Dense(len(trainY[0])))
model.add(Activation("softmax"))

# %%
# construct the training image generator for data augmentation
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.15,
                         width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
                         horizontal_flip=True, fill_mode="nearest")

# %%
# Setup hyper-parameters
EPOCHS = 50
BATCH_SIZE = 32
INIT_LEARNING_RATE = 1e-4

# %%
# initialize the optimizer and model
print("[INFO] compiling model...")
opt = Adam(lr=INIT_LEARNING_RATE, decay=INIT_LEARNING_RATE / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# %% [markdown]
# ### 4. Huấn luyện mô hình

# %%
# train the network
print("[INFO] training network for {} epochs...".format(EPOCHS))
H = model.fit(x=aug.flow(trainX, trainY, batch_size=BATCH_SIZE),
                         validation_data = (testX, testY),
                         steps_per_epoch = len(trainX) // BATCH_SIZE, 
                         epochs=EPOCHS)

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(np.arange(0, EPOCHS), H.history["loss"], label="train_loss")
ax.plot(np.arange(0, EPOCHS), H.history["val_loss"], label="val_loss")
ax.plot(np.arange(0, EPOCHS), H.history["accuracy"], label="train_acc")
ax.plot(np.arange(0, EPOCHS), H.history["val_accuracy"], label="val_acc")
ax.set_title("Training Loss and Accuracy on Dataset")
ax.set_xlabel("Epoch #")
ax.set_ylabel("Loss/Accuracy")

plt.xlim(0, EPOCHS)
plt.ylim(0, 1.01)
plt.legend(loc="lower left")

plt.show()

# %%
# Save the training progress to memory
if not os.path.exists("progress"):
    os.mkdir("progress")
name = datetime.datetime.now().strftime("%Y%m%d-%H%M")
plt.savefig("progress/plot_" + name)

# %% [markdown]
# ### Đánh giá mô hình

# %%
predictions = model.predict(x=testX, batch_size=BATCH_SIZE)
print(classification_report(y_true=testY.argmax(axis=1), y_pred=predictions.argmax(axis=1), target_names=le.classes_))

# %%
# Lưu mô hình
print("[INFO] Saving model...")
model.save("saved_model/deep_learning_model/model_" + name, save_format="h5")

# %%
# Lưu predicted labels
f = open("label_encoded/label_encoded" + name + ".pl", "wb")
f.write(pickle.dumps(le))
f.close()

# %% [markdown]
# ### <strike>Đánh giá mô hình trên tập dữ liệu unseen</strike>

# %% [markdown]
# ## Thực nghiệm trong thực tế

# %% [markdown]
# Tại mỗi thời điểm, webcam của máy tính sẽ ghi lại hình ảnh để thực hiện tác vụ phát hiện khuôn mặt giả mạo được mô tả dưới đây:
#
# - Bước 1: sử dụng một detector được hỗ trợ bởi thư viện OpenCV để phát hiện các khuôn mặt trong mỗi frame hình.
#
# - Bước 2: Đưa các khuôn mặt được phát hiện vào mô hình chúng ta đã huấn luyện được để phân loại đó là khuôn mặt thật hay giả mạo.
#
# - Bước 3: Thể hiện kết quả qua việc vẽ các bounding boxes (khung hình chữ nhật bao quanh khuôn mặt) và class (fake hoặc real) cho các khuôn mặt xuất hiện tại thời điểm đó.

# %% [markdown]
# ## Một số vấn đề

# %% [markdown]
# - Dữ liệu thu thập được ít nên các mô hình huấn luyện chưa có khả năng khái quá các khái niệm, hay nói cách khác đó là mô hình khi đưa vào sử dụng thực tế không có độ chính xác như mong đợi.
#
# - Ngoài độ đo là accuracy, precision, recall, bài toán Liveness detection được đánh giá bởi các một số độ đo chuẩn, đó là Equal Error Rate (EER), Attack Presentation Classification Error Rate (APCER), Bona fide presentation classification error rate(BPCER).
#
# - <strike>Sử dụng kĩ thuật Transfer Learning cho phương pháp dựa trên Deep Learning bằng các mô hình đã được huấn luyện như VGG, AlexNet, InceptionNet, ResNet.</strike>

# %% [markdown]
# ## Tham khảo

# %% [markdown]
# [1] A. Khodabakhsh, R. Ramachandra, K. Raja, P. Wasnik and C. Busch, "Fake Face Detection Methods: Can They Be Generalized?," 2018 International Conference of the Biometrics Special Interest Group (BIOSIG), Darmstadt, 2018, pp. 1-6, doi: 10.23919/BIOSIG.2018.8553251.
#
# [2] T. Ojala, M. Pietikainen and T. Maenpaa, "Multiresolution gray-scale and rotation invariant texture classification with local binary patterns," in IEEE Transactions on Pattern Analysis and Machine Intelligence, vol. 24, no. 7, pp. 971-987, July 2002, doi: 10.1109/TPAMI.2002.1017623.
#
# [3] [Local Binary Patterns with Python & OpenCV](https://www.pyimagesearch.com/2015/12/07/local-binary-patterns-with-python-opencv/)
#
# [4] [Real and Fake Face Detection](https://www.kaggle.com/ciplab/real-and-fake-face-detection)
#
# [5] [Liveness Detection with OpenCV](https://www.pyimagesearch.com/2019/03/11/liveness-detection-with-opencv/)

# %% [markdown]
# <center><i><b> ---- Hết---- </b></i></center>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/School_UIT/Semester IV/[CS114] Machine Learning/Working/CS114.K21.KHTN/Capstone_FakeFaceDetection
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/School_UIT/Semester IV/[CS114] Machine Learning/Working/CS114.K21.KHTN/Capstone_FakeFaceDetection

# %%
# !ls
# Out:
#  blur_detection.py		        hand_crafted_model.py
# '[Capstone] Anti-spoofing face.ipynb'   images
#  classifier			        label_encoded
#  config.py			        __pycache__
#  dataset			        README.md
#  demo.py			        requirements.txt
#  Documents			        saved_model
#  face_detector			        train.py
#  figures			        utils.py
#  gather_data.py			        videos

# %%
! zip -r dataset dataset
# Out:
# Scanning files
#   adding: dataset/ (stored 0%)
#   adding: dataset/fake/ (stored 0%)
#   adding: dataset/fake/fake01/ (stored 0%)
#   adding: dataset/fake/fake01/0005.png (deflated 4%)
#   adding: dataset/fake/fake01/0002.png (deflated 11%)
#   adding: dataset/fake/fake01/0010.png (deflated 8%)
#   adding: dataset/fake/fake01/0004.png (deflated 5%)
#   adding: dataset/fake/fake01/0011.png (deflated 7%)
#   adding: dataset/fake/fake01/0009.png (deflated 4%)
#   adding: dataset/fake/fake01/0006.png (deflated 6%)
#   adding: dataset/fake/fake01/0001.png (deflated 13%)
#   adding: dataset/fake/fake01/0013.png (deflated 5%)
#   adding: dataset/fake/fake01/0539.png (deflated 7%)
#   adding: dataset/fake/fake01/0541.png (deflated 5%)
#   adding: dataset/fake/fake01/0536.png (deflated 7%)
#   adding: dataset/fake/fake01/0537.png (deflated 7%)
#   adding: dataset/fake/fake01/0544.png (deflated 6%)
#   adding: dataset/fake/fake01/0545.png (deflated 7%)
#   adding: dataset/fake/fake01/0548.png (deflated 7%)
#   adding: dataset/fake/fake01/0547.png (deflated 7%)
#   adding: dataset/fake/fake01/0556.png (deflated 8%)
#   adding: dataset/fake/fake01/0550.png (deflated 12%)
#   adding: dataset/fake/fake01/0555.png (deflated 7%)
#   adding: dataset/fake/fake01/0553.png (deflated 7%)
#   adding: dataset/fake/fake01/0546.png (deflated 8%)
#   adding: dataset/fake/fake01/0549.png (deflated 7%)
#   adding: dataset/fake/fake01/0554.png (deflated 7%)
#   adding: dataset/fake/fake01/0551.png (deflated 10%)
#   adding: dataset/fake/fake01/0552.png (deflated 8%)
#   adding: dataset/fake/fake01/0557.png (deflated 10%)
#   adding: dataset/fake/fake02/ (stored 0%)
#   adding: dataset/fake/fake02/0010.png (deflated 15%)
#   adding: dataset/fake/fake02/0008.png (deflated 13%)
#   adding: dataset/fake/fake02/0005.png (deflated 11%)
#   adding: dataset/fake/fake02/0000.png (deflated 7%)
#   adding: dataset/fake/fake02/0007.png (deflated 11%)
#   adding: dataset/fake/fake02/0006.png (deflated 14%)
#   adding: dataset/fake/fake02/0002.png (deflated 11%)
#   adding: dataset/fake/fake02/0004.png (deflated 12%)
#   adding: dataset/fake/fake02/0009.png (deflated 14%)
#   adding: dataset/fake/fake02/0001.png (deflated 9%)
#   adding: dataset/fake/fake02/0003.png (deflated 8%)
#   adding: dataset/fake/fake02/0015.png (deflated 15%)
#   adding: dataset/fake/fake02/0019.png (deflated 11%)
#   adding: dataset/fake/fake02/0018.png (deflated 15%)
#   adding: dataset/fake/fake02/0020.png (deflated 11%)
#   adding: dataset/fake/fake02/0023.png (deflated 13%)
#   adding: dataset/fake/fake02/0021.png (deflated 12%)
#   adding: dataset/fake/fake02/0012.png (deflated 12%)
#   adding: dataset/fake/fake02/0022.png (deflated 16%)
#   adding: dataset/fake/fake02/0014.png (deflated 15%)
#   adding: dataset/fake/fake02/0017.png (deflated 13%)
#   adding: dataset/fake/fake02/0013.png (deflated 16%)
#   adding: dataset/fake/fake02/0011.png (deflated 12%)
#   adding: dataset/fake/fake02/0016.png (deflated 13%)
#   adding: dataset/fake/fake02/0025.png (deflated 17%)
#   adding: dataset/fake/fake02/0024.png (deflated 14%)
#   adding: dataset/fake/fake02/0033.png (deflated 15%)
#   adding: dataset/fake/fake02/0031.png (deflated 14%)
#   adding: dataset/fake/fake02/0027.png (deflated 13%)
#   adding: dataset/fake/fake02/0037.png (deflated 14%)
#   adding: dataset/fake/fake02/0036.png (deflated 14%)
#   adding: dataset/fake/fake02/0029.png (deflated 17%)
#   adding: dataset/fake/fake02/0028.png (deflated 16%)
#   adding: dataset/fake/fake02/0030.png (deflated 15%)
#   adding: dataset/fake/fake02/0035.png (deflated 11%)
#   adding: dataset/fake/fake02/0026.png (deflated 17%)
#   adding: dataset/fake/fake02/0032.png (deflated 13%)
#   adding: dataset/fake/fake02/0034.png (deflated 15%)
#   adding: dataset/fake/fake02/0040.png (deflated 16%)
#   adding: dataset/fake/fake02/0045.png (deflated 14%)
#   adding: dataset/fake/fake02/0043.png (deflated 11%)
#   adding: dataset/fake/fake02/0044.png (deflated 14%)
#   adding: dataset/fake/fake02/0039.png (deflated 18%)
#   adding: dataset/fake/fake02/0042.png (deflated 13%)
#   adding: dataset/fake/fake02/0038.png (deflated 12%)
#   adding: dataset/fake/fake02/0041.png (deflated 18%)
#   adding: dataset/fake/fake02/0055.png (deflated 12%)
#   adding: dataset/fake/fake02/0046.png (deflated 15%)
#   adding: dataset/fake/fake02/0052.png (deflated 13%)
#   adding: dataset/fake/fake02/0047.png (deflated 11%)
#   adding: dataset/fake/fake02/0049.png (deflated 11%)
#   adding: dataset/fake/fake02/0048.png (deflated 12%)
#   adding: dataset/fake/fake02/0054.png (deflated 9%)
#   adding: dataset/fake/fake02/0050.png (deflated 13%)
#   adding: dataset/fake/fake02/0053.png (deflated 14%)
#   adding: dataset/fake/fake02/0056.png (deflated 13%)
#   adding: dataset/fake/fake02/0051.png (deflated 11%)
#   adding: dataset/fake/fake02/0063.png (deflated 14%)
#   adding: dataset/fake/fake02/0065.png (deflated 14%)
#   adding: dataset/fake/fake02/0062.png (deflated 11%)
#   adding: dataset/fake/fake02/0072.png (deflated 13%)
#   adding: dataset/fake/fake02/0068.png (deflated 13%)
#   adding: dataset/fake/fake02/0066.png (deflated 11%)
#   adding: dataset/fake/fake02/0070.png (deflated 14%)
#   adding: dataset/fake/fake02/0071.png (deflated 14%)
#   adding: dataset/fake/fake02/0067.png (deflated 13%)
#   adding: dataset/fake/fake02/0057.png (deflated 13%)
#   adding: dataset/fake/fake02/0061.png (deflated 12%)
#   adding: dataset/fake/fake02/0069.png (deflated 14%)
#   adding: dataset/fake/fake02/0059.png (deflated 12%)
#   adding: dataset/fake/fake02/0058.png (deflated 14%)
#   adding: dataset/fake/fake02/0064.png (deflated 12%)
#   adding: dataset/fake/fake02/0060.png (deflated 11%)
#   adding: dataset/fake/fake02/0079.png (deflated 14%)
#   adding: dataset/fake/fake02/0075.png (deflated 12%)
#   adding: dataset/fake/fake02/0074.png (deflated 11%)
#   adding: dataset/fake/fake02/0078.png (deflated 15%)
#   adding: dataset/fake/fake02/0077.png (deflated 13%)
#   adding: dataset/fake/fake02/0076.png (deflated 15%)
#   adding: dataset/fake/fake02/0073.png (deflated 10%)
#   adding: dataset/fake/fake02/0080.png (deflated 16%)
#   adding: dataset/fake/fake02/0081.png (deflated 13%)
#   adding: dataset/fake/fake02/0085.png (deflated 14%)
#   adding: dataset/fake/fake02/0084.png (deflated 14%)
#   adding: dataset/fake/fake02/0082.png (deflated 16%)
#   adding: dataset/fake/fake02/0083.png (deflated 13%)
#   adding: dataset/fake/fake02/0094.png (deflated 10%)
#   adding: dataset/fake/fake02/0101.png (deflated 10%)
#   adding: dataset/fake/fake02/0098.png (deflated 12%)
#   adding: dataset/fake/fake02/0104.png (deflated 11%)
#   adding: dataset/fake/fake02/0088.png (deflated 17%)
#   adding: dataset/fake/fake02/0099.png (deflated 12%)
#   adding: dataset/fake/fake02/0102.png (deflated 9%)
#   adding: dataset/fake/fake02/0090.png (deflated 15%)
#   adding: dataset/fake/fake02/0093.png (deflated 10%)
#   adding: dataset/fake/fake02/0087.png (deflated 15%)
#   adding: dataset/fake/fake02/0097.png (deflated 12%)
#   adding: dataset/fake/fake02/0095.png (deflated 15%)
#   adding: dataset/fake/fake02/0091.png (deflated 12%)
#   adding: dataset/fake/fake02/0103.png (deflated 14%)
#   adding: dataset/fake/fake02/0100.png (deflated 10%)
#   adding: dataset/fake/fake02/0092.png (deflated 12%)
#   adding: dataset/fake/fake02/0086.png (deflated 14%)
#   adding: dataset/fake/fake02/0105.png (deflated 10%)
#   adding: dataset/fake/fake02/0106.png (deflated 10%)
#   adding: dataset/fake/fake02/0089.png (deflated 15%)
#   adding: dataset/fake/fake02/0096.png (deflated 13%)
#   adding: dataset/fake/fake02/0111.png (deflated 11%)
#   adding: dataset/fake/fake02/0119.png (deflated 12%)
#   adding: dataset/fake/fake02/0107.png (deflated 11%)
#   adding: dataset/fake/fake02/0116.png (deflated 12%)
#   adding: dataset/fake/fake02/0108.png (deflated 12%)
#   adding: dataset/fake/fake02/0110.png (deflated 11%)
#   adding: dataset/fake/fake02/0117.png (deflated 10%)
#   adding: dataset/fake/fake02/0115.png (deflated 9%)
#   adding: dataset/fake/fake02/0112.png (deflated 10%)
#   adding: dataset/fake/fake02/0114.png (deflated 10%)
#   adding: dataset/fake/fake02/0109.png (deflated 9%)
#   adding: dataset/fake/fake02/0118.png (deflated 11%)
#   adding: dataset/fake/fake02/0113.png (deflated 10%)
#   adding: dataset/fake/fake02/0120.png (deflated 10%)
#   adding: dataset/fake/fake02/0123.png (deflated 11%)
#   adding: dataset/fake/fake02/0121.png (deflated 10%)
#   adding: dataset/fake/fake02/0122.png (deflated 12%)
#   adding: dataset/fake/fake02/0125.png (deflated 10%)
#   adding: dataset/fake/fake02/0124.png (deflated 11%)
#   adding: dataset/fake/fake02/0126.png (deflated 14%)
#   adding: dataset/fake/fake02/0127.png (deflated 16%)
#   adding: dataset/fake/fake02/0135.png (deflated 14%)
#   adding: dataset/fake/fake02/0129.png (deflated 12%)
#   adding: dataset/fake/fake02/0131.png (deflated 14%)
#   adding: dataset/fake/fake02/0134.png (deflated 14%)
#   adding: dataset/fake/fake02/0128.png (deflated 12%)
#   adding: dataset/fake/fake02/0133.png (deflated 9%)
#   adding: dataset/fake/fake02/0132.png (deflated 12%)
#   adding: dataset/fake/fake02/0130.png (deflated 10%)
#   adding: dataset/fake/fake02/0140.png (deflated 11%)
#   adding: dataset/fake/fake02/0139.png (deflated 10%)
#   adding: dataset/fake/fake02/0141.png (deflated 9%)
#   adding: dataset/fake/fake02/0150.png (deflated 11%)
#   adding: dataset/fake/fake02/0147.png (deflated 13%)
#   adding: dataset/fake/fake02/0136.png (deflated 11%)
#   adding: dataset/fake/fake02/0148.png (deflated 13%)
#   adding: dataset/fake/fake02/0145.png (deflated 9%)
#   adding: dataset/fake/fake02/0149.png (deflated 12%)
#   adding: dataset/fake/fake02/0142.png (deflated 9%)
#   adding: dataset/fake/fake02/0144.png (deflated 9%)
#   adding: dataset/fake/fake02/0146.png (deflated 11%)
#   adding: dataset/fake/fake02/0138.png (deflated 10%)
#   adding: dataset/fake/fake02/0143.png (deflated 11%)
#   adding: dataset/fake/fake02/0137.png (deflated 11%)
#   adding: dataset/fake/fake02/0154.png (deflated 14%)
#   adding: dataset/fake/fake02/0152.png (deflated 14%)
#   adding: dataset/fake/fake02/0153.png (deflated 12%)
#   adding: dataset/fake/fake02/0151.png (deflated 10%)
#   adding: dataset/fake/fake02/0157.png (deflated 12%)
#   adding: dataset/fake/fake02/0161.png (deflated 14%)
#   adding: dataset/fake/fake02/0160.png (deflated 13%)
#   adding: dataset/fake/fake02/0158.png (deflated 12%)
#   adding: dataset/fake/fake02/0156.png (deflated 10%)
#   adding: dataset/fake/fake02/0159.png (deflated 16%)
#   adding: dataset/fake/fake02/0163.png (deflated 15%)
#   adding: dataset/fake/fake02/0155.png (deflated 10%)
#   adding: dataset/fake/fake02/0164.png (deflated 13%)
#   adding: dataset/fake/fake02/0165.png (deflated 12%)
#   adding: dataset/fake/fake02/0162.png (deflated 12%)
#   adding: dataset/fake/fake02/0174.png (deflated 11%)
#   adding: dataset/fake/fake02/0178.png (deflated 10%)
#   adding: dataset/fake/fake02/0175.png (deflated 12%)
#   adding: dataset/fake/fake02/0166.png (deflated 14%)
#   adding: dataset/fake/fake02/0181.png (deflated 14%)
#   adding: dataset/fake/fake02/0173.png (deflated 10%)
#   adding: dataset/fake/fake02/0167.png (deflated 11%)
#   adding: dataset/fake/fake02/0177.png (deflated 10%)
#   adding: dataset/fake/fake02/0176.png (deflated 12%)
#   adding: dataset/fake/fake02/0172.png (deflated 11%)
#   adding: dataset/fake/fake02/0168.png (deflated 11%)
#   adding: dataset/fake/fake02/0179.png (deflated 11%)
#   adding: dataset/fake/fake02/0171.png (deflated 15%)
#   adding: dataset/fake/fake02/0169.png (deflated 14%)
#   adding: dataset/fake/fake02/0170.png (deflated 13%)
#   adding: dataset/fake/fake02/0180.png (deflated 15%)
#   adding: dataset/fake/fake02/0183.png (deflated 14%)
#   adding: dataset/fake/fake02/0182.png (deflated 16%)
#   adding: dataset/fake/fake02/0192.png (deflated 10%)
#   adding: dataset/fake/fake02/0186.png (deflated 11%)
#   adding: dataset/fake/fake02/0189.png (deflated 9%)
#   adding: dataset/fake/fake02/0193.png (deflated 9%)
#   adding: dataset/fake/fake02/0191.png (deflated 12%)
#   adding: dataset/fake/fake02/0190.png (deflated 9%)
#   adding: dataset/fake/fake02/0184.png (deflated 11%)
#   adding: dataset/fake/fake02/0185.png (deflated 10%)
#   adding: dataset/fake/fake02/0187.png (deflated 10%)
#   adding: dataset/fake/fake02/0195.png (deflated 10%)
#   adding: dataset/fake/fake02/0188.png (deflated 8%)
#   adding: dataset/fake/fake02/0194.png (deflated 12%)
#   adding: dataset/fake/fake02/0203.png (deflated 9%)
#   adding: dataset/fake/fake02/0197.png (deflated 8%)
#   adding: dataset/fake/fake02/0204.png (deflated 14%)
#   adding: dataset/fake/fake02/0199.png (deflated 11%)
#   adding: dataset/fake/fake02/0205.png (deflated 13%)
#   adding: dataset/fake/fake02/0200.png (deflated 9%)
#   adding: dataset/fake/fake02/0196.png (deflated 8%)
#   adding: dataset/fake/fake02/0202.png (deflated 10%)
#   adding: dataset/fake/fake02/0198.png (deflated 13%)
#   adding: dataset/fake/fake02/0201.png (deflated 9%)
#   adding: dataset/fake/fake02/0209.png (deflated 11%)
#   adding: dataset/fake/fake02/0210.png (deflated 9%)
#   adding: dataset/fake/fake02/0206.png (deflated 13%)
#   adding: dataset/fake/fake02/0211.png (deflated 11%)
#   adding: dataset/fake/fake02/0207.png (deflated 10%)
#   adding: dataset/fake/fake02/0214.png (deflated 10%)
#   adding: dataset/fake/fake02/0213.png (deflated 10%)
#   adding: dataset/fake/fake02/0208.png (deflated 9%)
#   adding: dataset/fake/fake02/0212.png (deflated 11%)
#   adding: dataset/fake/fake02/0226.png (deflated 11%)
#   adding: dataset/fake/fake02/0228.png (deflated 9%)
#   adding: dataset/fake/fake02/0215.png (deflated 12%)
#   adding: dataset/fake/fake02/0225.png (deflated 10%)
#   adding: dataset/fake/fake02/0216.png (deflated 12%)
#   adding: dataset/fake/fake02/0217.png (deflated 13%)
#   adding: dataset/fake/fake02/0219.png (deflated 11%)
#   adding: dataset/fake/fake02/0220.png (deflated 9%)
#   adding: dataset/fake/fake02/0218.png (deflated 11%)
#   adding: dataset/fake/fake02/0221.png (deflated 10%)
#   adding: dataset/fake/fake02/0222.png (deflated 9%)
#   adding: dataset/fake/fake02/0224.png (deflated 11%)
#   adding: dataset/fake/fake02/0227.png (deflated 10%)
#   adding: dataset/fake/fake02/0223.png (deflated 12%)
#   adding: dataset/fake/fake02/0231.png (deflated 13%)
#   adding: dataset/fake/fake02/0233.png (deflated 11%)
#   adding: dataset/fake/fake02/0234.png (deflated 10%)
#   adding: dataset/fake/fake02/0232.png (deflated 12%)
#   adding: dataset/fake/fake02/0229.png (deflated 14%)
#   adding: dataset/fake/fake02/0235.png (deflated 13%)
#   adding: dataset/fake/fake02/0230.png (deflated 13%)
#   adding: dataset/fake/fake02/0236.png (deflated 13%)
#   adding: dataset/fake/fake02/0237.png (deflated 12%)
#   adding: dataset/fake/fake02/0250.png (deflated 15%)
#   adding: dataset/fake/fake02/0238.png (deflated 10%)
#   adding: dataset/fake/fake02/0247.png (deflated 10%)
#   adding: dataset/fake/fake02/0251.png (deflated 11%)
#   adding: dataset/fake/fake02/0242.png (deflated 14%)
#   adding: dataset/fake/fake02/0245.png (deflated 11%)
#   adding: dataset/fake/fake02/0249.png (deflated 15%)
#   adding: dataset/fake/fake02/0240.png (deflated 11%)
#   adding: dataset/fake/fake02/0243.png (deflated 10%)
#   adding: dataset/fake/fake02/0253.png (deflated 14%)
#   adding: dataset/fake/fake02/0244.png (deflated 10%)
#   adding: dataset/fake/fake02/0252.png (deflated 11%)
#   adding: dataset/fake/fake02/0246.png (deflated 12%)
#   adding: dataset/fake/fake02/0239.png (deflated 12%)
#   adding: dataset/fake/fake02/0248.png (deflated 10%)
#   adding: dataset/fake/fake02/0241.png (deflated 11%)
#   adding: dataset/fake/fake02/0256.png (deflated 12%)
#   adding: dataset/fake/fake02/0258.png (deflated 13%)
#   adding: dataset/fake/fake02/0255.png (deflated 10%)
#   adding: dataset/fake/fake02/0257.png (deflated 11%)
#   adding: dataset/fake/fake02/0254.png (deflated 11%)
#   adding: dataset/fake/fake02/0260.png (deflated 15%)
#   adding: dataset/fake/fake02/0264.png (deflated 14%)
#   adding: dataset/fake/fake02/0261.png (deflated 13%)
#   adding: dataset/fake/fake02/0268.png (deflated 13%)
#   adding: dataset/fake/fake02/0262.png (deflated 14%)
#   adding: dataset/fake/fake02/0259.png (deflated 11%)
#   adding: dataset/fake/fake02/0263.png (deflated 12%)
#   adding: dataset/fake/fake02/0267.png (deflated 15%)
#   adding: dataset/fake/fake02/0266.png (deflated 12%)
#   adding: dataset/fake/fake02/0265.png (deflated 12%)
#   adding: dataset/fake/fake03/ (stored 0%)
#   adding: dataset/fake/fake03/0001.png (deflated 12%)
#   adding: dataset/fake/fake03/0000.png (deflated 11%)
#   adding: dataset/fake/fake03/0004.png (deflated 13%)
#   adding: dataset/fake/fake03/0002.png (deflated 11%)
#   adding: dataset/fake/fake03/0005.png (deflated 17%)
#   adding: dataset/fake/fake03/0019.png (deflated 10%)
#   adding: dataset/fake/fake03/0012.png (deflated 14%)
#   adding: dataset/fake/fake03/0017.png (deflated 11%)
#   adding: dataset/fake/fake03/0008.png (deflated 11%)
#   adding: dataset/fake/fake03/0009.png (deflated 15%)
#   adding: dataset/fake/fake03/0006.png (deflated 17%)
#   adding: dataset/fake/fake03/0020.png (deflated 12%)
#   adding: dataset/fake/fake03/0007.png (deflated 17%)
#   adding: dataset/fake/fake03/0016.png (deflated 15%)
#   adding: dataset/fake/fake03/0022.png (deflated 10%)
#   adding: dataset/fake/fake03/0021.png (deflated 8%)
#   adding: dataset/fake/fake03/0013.png (deflated 13%)
#   adding: dataset/fake/fake03/0010.png (deflated 13%)
#   adding: dataset/fake/fake03/0018.png (deflated 11%)
#   adding: dataset/fake/fake03/0014.png (deflated 11%)
#   adding: dataset/fake/fake03/0015.png (deflated 14%)
#   adding: dataset/fake/fake03/0011.png (deflated 12%)
#   adding: dataset/fake/fake03/0024.png (deflated 10%)
#   adding: dataset/fake/fake03/0023.png (deflated 11%)
#   adding: dataset/fake/fake03/0025.png (deflated 11%)
#   adding: dataset/fake/fake03/0026.png (deflated 10%)
#   adding: dataset/fake/fake03/0032.png (deflated 12%)
#   adding: dataset/fake/fake03/0029.png (deflated 11%)
#   adding: dataset/fake/fake03/0031.png (deflated 14%)
#   adding: dataset/fake/fake03/0030.png (deflated 8%)
#   adding: dataset/fake/fake03/0027.png (deflated 10%)
#   adding: dataset/fake/fake03/0028.png (deflated 10%)
#   adding: dataset/fake/fake03/0043.png (deflated 9%)
#   adding: dataset/fake/fake03/0037.png (deflated 10%)
#   adding: dataset/fake/fake03/0041.png (deflated 11%)
#   adding: dataset/fake/fake03/0042.png (deflated 14%)
#   adding: dataset/fake/fake03/0039.png (deflated 11%)
#   adding: dataset/fake/fake03/0035.png (deflated 12%)
#   adding: dataset/fake/fake03/0040.png (deflated 10%)
#   adding: dataset/fake/fake03/0038.png (deflated 8%)
#   adding: dataset/fake/fake03/0036.png (deflated 11%)
#   adding: dataset/fake/fake03/0033.png (deflated 12%)
#   adding: dataset/fake/fake03/0034.png (deflated 8%)
#   adding: dataset/fake/fake03/0047.png (deflated 8%)
#   adding: dataset/fake/fake03/0052.png (deflated 7%)
#   adding: dataset/fake/fake03/0053.png (deflated 6%)
#   adding: dataset/fake/fake03/0045.png (deflated 7%)
#   adding: dataset/fake/fake03/0044.png (deflated 10%)
#   adding: dataset/fake/fake03/0048.png (deflated 9%)
#   adding: dataset/fake/fake03/0054.png (deflated 10%)
#   adding: dataset/fake/fake03/0049.png (deflated 10%)
#   adding: dataset/fake/fake03/0046.png (deflated 8%)
#   adding: dataset/fake/fake03/0051.png (deflated 8%)
#   adding: dataset/fake/fake03/0055.png (deflated 9%)
#   adding: dataset/fake/fake03/0050.png (deflated 10%)
#   adding: dataset/fake/fake03/0061.png (deflated 7%)
#   adding: dataset/fake/fake03/0062.png (deflated 7%)
#   adding: dataset/fake/fake03/0056.png (deflated 16%)
#   adding: dataset/fake/fake03/0059.png (deflated 9%)
#   adding: dataset/fake/fake03/0060.png (deflated 9%)
#   adding: dataset/fake/fake03/0057.png (deflated 11%)
#   adding: dataset/fake/fake03/0058.png (deflated 8%)
#   adding: dataset/fake/fake03/0075.png (deflated 9%)
#   adding: dataset/fake/fake03/0069.png (deflated 12%)
#   adding: dataset/fake/fake03/0074.png (deflated 9%)
#   adding: dataset/fake/fake03/0070.png (deflated 13%)
#   adding: dataset/fake/fake03/0072.png (deflated 12%)
#   adding: dataset/fake/fake03/0067.png (deflated 11%)
# ...
#   adding: dataset/real/real05/0260.png (deflated 4%)
#   adding: dataset/real/real05/0261.png (deflated 4%)
#   adding: dataset/real/real05/0262.png (deflated 6%)
#   adding: dataset/real/real05/0263.png (deflated 5%)
#   adding: dataset/real/real05/0264.png (deflated 5%)
#   adding: dataset/real/real05/0265.png (deflated 5%)
#   adding: dataset/real/real05/0266.png (deflated 5%)
#   adding: dataset/real/real05/0267.png (deflated 5%)
#   adding: dataset/real/real05/0259.png (deflated 4%)
#   adding: dataset/real/real05/0272.png (deflated 5%)
#   adding: dataset/real/real05/0273.png (deflated 5%)
#   adding: dataset/real/real05/0271.png (deflated 5%)
#   adding: dataset/real/real05/0270.png (deflated 5%)
#   adding: dataset/real/real05/0277.png (deflated 5%)
#   adding: dataset/real/real05/0276.png (deflated 5%)
#   adding: dataset/real/real05/0275.png (deflated 5%)
#   adding: dataset/real/real05/0274.png (deflated 5%)
#   adding: dataset/real/real05/0268.png (deflated 5%)
#   adding: dataset/real/real05/0269.png (deflated 5%)
#   adding: dataset/real/real05/0140.png (deflated 5%)
#   adding: dataset/real/real05/0137.png (deflated 4%)
#   adding: dataset/real/real05/0135.png (deflated 4%)
#   adding: dataset/real/real05/0130.png (deflated 5%)
#   adding: dataset/real/real05/0139.png (deflated 5%)
#   adding: dataset/real/real05/0149.png (deflated 5%)
#   adding: dataset/real/real05/0148.png (deflated 4%)
#   adding: dataset/real/real05/0150.png (deflated 4%)
#   adding: dataset/real/real05/0146.png (deflated 5%)
#   adding: dataset/real/real05/0144.png (deflated 5%)
#   adding: dataset/real/real05/0141.png (deflated 7%)
#   adding: dataset/real/real05/0143.png (deflated 6%)
#   adding: dataset/real/real05/0142.png (deflated 6%)
#   adding: dataset/real/real05/0138.png (deflated 4%)
#   adding: dataset/real/real05/0161.png (deflated 4%)
#   adding: dataset/real/real05/0160.png (deflated 4%)
#   adding: dataset/real/real05/0156.png (deflated 4%)
#   adding: dataset/real/real05/0153.png (deflated 4%)
#   adding: dataset/real/real05/0154.png (deflated 4%)
#   adding: dataset/real/real05/0155.png (deflated 4%)
#   adding: dataset/real/real05/0152.png (deflated 4%)
#   adding: dataset/real/real05/0147.png (deflated 4%)
#   adding: dataset/real/real05/0151.png (deflated 4%)
#   adding: dataset/real/real05/0145.png (deflated 5%)
#   adding: dataset/real/real05/0167.png (deflated 6%)
#   adding: dataset/real/real05/0166.png (deflated 4%)
#   adding: dataset/real/real05/0165.png (deflated 4%)
#   adding: dataset/real/real05/0164.png (deflated 4%)
#   adding: dataset/real/real05/0170.png (deflated 5%)
#   adding: dataset/real/real05/0171.png (deflated 5%)
#   adding: dataset/real/real05/0157.png (deflated 4%)
#   adding: dataset/real/real05/0158.png (deflated 4%)
#   adding: dataset/real/real05/0159.png (deflated 4%)
#   adding: dataset/real/real05/0162.png (deflated 4%)
#   adding: dataset/real/real05/0179.png (deflated 5%)
#   adding: dataset/real/real05/0174.png (deflated 5%)
#   adding: dataset/real/real05/0175.png (deflated 5%)
#   adding: dataset/real/real05/0176.png (deflated 5%)
#   adding: dataset/real/real05/0177.png (deflated 5%)
#   adding: dataset/real/real05/0172.png (deflated 5%)
#   adding: dataset/real/real05/0173.png (deflated 5%)
#   adding: dataset/real/real05/0163.png (deflated 4%)
#   adding: dataset/real/real05/0169.png (deflated 5%)
#   adding: dataset/real/real05/0168.png (deflated 6%)
#   adding: dataset/real/real05/0188.png (deflated 4%)
#   adding: dataset/real/real05/0187.png (deflated 5%)
#   adding: dataset/real/real05/0181.png (deflated 5%)
#   adding: dataset/real/real05/0180.png (deflated 5%)
#   adding: dataset/real/real05/0183.png (deflated 5%)
#   adding: dataset/real/real05/0182.png (deflated 5%)
#   adding: dataset/real/real05/0185.png (deflated 5%)
#   adding: dataset/real/real05/0184.png (deflated 5%)
#   adding: dataset/real/real05/0186.png (deflated 5%)
#   adding: dataset/real/real05/0178.png (deflated 6%)
#   adding: dataset/real/real05/0196.png (deflated 5%)
#   adding: dataset/real/real05/0197.png (deflated 6%)
#   adding: dataset/real/real05/0198.png (deflated 6%)
#   adding: dataset/real/real05/0194.png (deflated 4%)
#   adding: dataset/real/real05/0195.png (deflated 5%)
#   adding: dataset/real/real05/0192.png (deflated 4%)
#   adding: dataset/real/real05/0193.png (deflated 4%)
#   adding: dataset/real/real05/0189.png (deflated 5%)
#   adding: dataset/real/real05/0190.png (deflated 5%)
#   adding: dataset/real/real05/0191.png (deflated 5%)
#   adding: dataset/real/real05/0207.png (deflated 4%)
#   adding: dataset/real/real05/0204.png (deflated 4%)
#   adding: dataset/real/real05/0208.png (deflated 4%)
#   adding: dataset/real/real05/0209.png (deflated 4%)
#   adding: dataset/real/real05/0205.png (deflated 5%)
#   adding: dataset/real/real05/0202.png (deflated 4%)
#   adding: dataset/real/real05/0203.png (deflated 4%)
#   adding: dataset/real/real05/0200.png (deflated 5%)
#   adding: dataset/real/real05/0201.png (deflated 5%)
#   adding: dataset/real/real05/0199.png (deflated 6%)
#   adding: dataset/real/real05/0067.png (deflated 4%)
#   adding: dataset/real/real05/0065.png (deflated 4%)
#   adding: dataset/real/real05/0068.png (deflated 4%)
#   adding: dataset/real/real05/0069.png (deflated 5%)
#   adding: dataset/real/real05/0071.png (deflated 5%)
#   adding: dataset/real/real05/0058.png (deflated 4%)
#   adding: dataset/real/real05/0044.png (deflated 4%)
#   adding: dataset/real/real05/0052.png (deflated 5%)
#   adding: dataset/real/real05/0064.png (deflated 4%)
#   adding: dataset/real/real05/0066.png (deflated 4%)
#   adding: dataset/real/real05/0073.png (deflated 5%)
#   adding: dataset/real/real05/0072.png (deflated 5%)
#   adding: dataset/real/real05/0080.png (deflated 4%)
#   adding: dataset/real/real05/0081.png (deflated 4%)
#   adding: dataset/real/real05/0082.png (deflated 4%)
#   adding: dataset/real/real05/0079.png (deflated 4%)
#   adding: dataset/real/real05/0078.png (deflated 5%)
#   adding: dataset/real/real05/0062.png (deflated 4%)
#   adding: dataset/real/real05/0063.png (deflated 4%)
#   adding: dataset/real/real05/0070.png (deflated 5%)
#   adding: dataset/real/real05/0089.png (deflated 4%)
#   adding: dataset/real/real05/0084.png (deflated 4%)
#   adding: dataset/real/real05/0086.png (deflated 4%)
#   adding: dataset/real/real05/0087.png (deflated 4%)
#   adding: dataset/real/real05/0075.png (deflated 5%)
#   adding: dataset/real/real05/0074.png (deflated 5%)
#   adding: dataset/real/real05/0077.png (deflated 5%)
#   adding: dataset/real/real05/0076.png (deflated 4%)
#   adding: dataset/real/real05/0083.png (deflated 5%)
#   adding: dataset/real/real05/0085.png (deflated 4%)
#   adding: dataset/real/real05/0100.png (deflated 6%)
#   adding: dataset/real/real05/0102.png (deflated 5%)
#   adding: dataset/real/real05/0093.png (deflated 4%)
#   adding: dataset/real/real05/0092.png (deflated 4%)
#   adding: dataset/real/real05/0091.png (deflated 5%)
#   adding: dataset/real/real05/0090.png (deflated 4%)
#   adding: dataset/real/real05/0094.png (deflated 4%)
#   adding: dataset/real/real05/0088.png (deflated 4%)
#   adding: dataset/real/real05/0095.png (deflated 5%)
#   adding: dataset/real/real05/0101.png (deflated 5%)
#   adding: dataset/real/real05/0106.png (deflated 5%)
#   adding: dataset/real/real05/0114.png (deflated 4%)
#   adding: dataset/real/real05/0115.png (deflated 4%)
#   adding: dataset/real/real05/0098.png (deflated 5%)
#   adding: dataset/real/real05/0112.png (deflated 4%)
#   adding: dataset/real/real05/0113.png (deflated 4%)
#   adding: dataset/real/real05/0097.png (deflated 6%)
#   adding: dataset/real/real05/0096.png (deflated 5%)
#   adding: dataset/real/real05/0107.png (deflated 5%)
#   adding: dataset/real/real05/0099.png (deflated 5%)
#   adding: dataset/real/real05/0103.png (deflated 5%)
#   adding: dataset/real/real05/0111.png (deflated 4%)
#   adding: dataset/real/real05/0109.png (deflated 4%)
#   adding: dataset/real/real05/0108.png (deflated 4%)
#   adding: dataset/real/real05/0105.png (deflated 5%)
#   adding: dataset/real/real05/0104.png (deflated 5%)
#   adding: dataset/real/real05/0110.png (deflated 4%)
#   adding: dataset/real/real05/0119.png (deflated 5%)
#   adding: dataset/real/real05/0116.png (deflated 4%)
#   adding: dataset/real/real05/0117.png (deflated 4%)
#   adding: dataset/real/real05/0129.png (deflated 5%)
#   adding: dataset/real/real05/0128.png (deflated 5%)
#   adding: dataset/real/real05/0127.png (deflated 5%)
#   adding: dataset/real/real05/0121.png (deflated 5%)
#   adding: dataset/real/real05/0123.png (deflated 5%)
#   adding: dataset/real/real05/0122.png (deflated 5%)
#   adding: dataset/real/real05/0120.png (deflated 5%)
#   adding: dataset/real/real05/0125.png (deflated 5%)
#   adding: dataset/real/real05/0124.png (deflated 4%)
#   adding: dataset/real/real05/0118.png (deflated 5%)
#   adding: dataset/real/real05/0132.png (deflated 5%)
#   adding: dataset/real/real05/0133.png (deflated 5%)
#   adding: dataset/real/real05/0134.png (deflated 4%)
#   adding: dataset/real/real05/0126.png (deflated 5%)
#   adding: dataset/real/real05/0136.png (deflated 4%)
#   adding: dataset/real/real05/0131.png (deflated 5%)
#   adding: dataset/real/real05/0011.png (deflated 5%)
#   adding: dataset/real/real05/0010.png (deflated 5%)
#   adding: dataset/real/real05/0012.png (deflated 5%)
#   adding: dataset/real/real05/0005.png (deflated 5%)
#   adding: dataset/real/real05/0015.png (deflated 5%)
#   adding: dataset/real/real05/0006.png (deflated 5%)
#   adding: dataset/real/real05/0000.png (deflated 6%)
#   adding: dataset/real/real05/0013.png (deflated 5%)
#   adding: dataset/real/real05/0007.png (deflated 5%)
#   adding: dataset/real/real05/0018.png (deflated 5%)
#   adding: dataset/real/real05/0014.png (deflated 4%)
#   adding: dataset/real/real05/0008.png (deflated 5%)
#   adding: dataset/real/real05/0001.png (deflated 6%)
#   adding: dataset/real/real05/0002.png (deflated 6%)
#   adding: dataset/real/real05/0003.png (deflated 6%)
#   adding: dataset/real/real05/0004.png (deflated 5%)
#   adding: dataset/real/real05/0019.png (deflated 5%)
#   adding: dataset/real/real05/0009.png (deflated 5%)
#   adding: dataset/real/real05/0023.png (deflated 5%)
#   adding: dataset/real/real05/0027.png (deflated 5%)
#   adding: dataset/real/real05/0025.png (deflated 6%)
#   adding: dataset/real/real05/0031.png (deflated 5%)
#   adding: dataset/real/real05/0030.png (deflated 5%)
#   adding: dataset/real/real05/0028.png (deflated 5%)
#   adding: dataset/real/real05/0016.png (deflated 5%)
#   adding: dataset/real/real05/0021.png (deflated 5%)
#   adding: dataset/real/real05/0020.png (deflated 4%)
#   adding: dataset/real/real05/0032.png (deflated 5%)
#   adding: dataset/real/real05/0026.png (deflated 6%)
#   adding: dataset/real/real05/0022.png (deflated 5%)
#   adding: dataset/real/real05/0017.png (deflated 5%)
#   adding: dataset/real/real05/0039.png (deflated 5%)
#   adding: dataset/real/real05/0038.png (deflated 5%)
#   adding: dataset/real/real05/0037.png (deflated 6%)
#   adding: dataset/real/real05/0036.png (deflated 7%)
#   adding: dataset/real/real05/0033.png (deflated 6%)
#   adding: dataset/real/real05/0035.png (deflated 5%)
#   adding: dataset/real/real05/0034.png (deflated 5%)
#   adding: dataset/real/real05/0024.png (deflated 5%)
#   adding: dataset/real/real05/0051.png (deflated 4%)
#   adding: dataset/real/real05/0043.png (deflated 4%)
#   adding: dataset/real/real05/0059.png (deflated 4%)
#   adding: dataset/real/real05/0056.png (deflated 4%)
#   adding: dataset/real/real05/0055.png (deflated 4%)
#   adding: dataset/real/real05/0054.png (deflated 4%)
#   adding: dataset/real/real05/0053.png (deflated 4%)
#   adding: dataset/real/real05/0029.png (deflated 5%)
#   adding: dataset/real/real05/0042.png (deflated 4%)
#   adding: dataset/real/real05/0050.png (deflated 4%)
#   adding: dataset/real/real05/0060.png (deflated 4%)
#   adding: dataset/real/real05/0061.png (deflated 4%)
#   adding: dataset/real/real05/0045.png (deflated 4%)
#   adding: dataset/real/real05/0046.png (deflated 4%)
#   adding: dataset/real/real05/0047.png (deflated 4%)
#   adding: dataset/real/real05/0040.png (deflated 5%)
#   adding: dataset/real/real05/0048.png (deflated 4%)
#   adding: dataset/real/real05/0049.png (deflated 4%)
#   adding: dataset/real/real05/0041.png (deflated 4%)
#   adding: dataset/real/real05/0057.png (deflated 4%)
#   adding: dataset/real/real04/ (stored 0%)
#   adding: dataset/real/real04/0029.png (deflated 5%)
#   adding: dataset/real/real04/0026.png (deflated 5%)
#   adding: dataset/real/real04/0024.png (deflated 5%)
#   adding: dataset/real/real04/0027.png (deflated 5%)
#   adding: dataset/real/real04/0025.png (deflated 5%)
#   adding: dataset/real/real04/0073.png (deflated 6%)
#   adding: dataset/real/real04/0072.png (deflated 5%)
#   adding: dataset/real/real04/0063.png (deflated 10%)
#   adding: dataset/real/real04/0066.png (deflated 6%)
#   adding: dataset/real/real04/0069.png (deflated 6%)
#   adding: dataset/real/real04/0065.png (deflated 6%)
#   adding: dataset/real/real04/0064.png (deflated 6%)
#   adding: dataset/real/real04/0057.png (deflated 6%)
#   adding: dataset/real/real04/0068.png (deflated 6%)
#   adding: dataset/real/real04/0056.png (deflated 6%)
#   adding: dataset/real/real04/0049.png (deflated 6%)
#   adding: dataset/real/real04/0055.png (deflated 6%)
#   adding: dataset/real/real04/0054.png (deflated 7%)
#   adding: dataset/real/real04/0048.png (deflated 5%)
#   adding: dataset/real/real04/0053.png (deflated 9%)
#   adding: dataset/real/real04/0003.png (deflated 5%)
#   adding: dataset/real/real04/0074.png (deflated 6%)
#   adding: dataset/real/real04/0079.png (deflated 7%)
#   adding: dataset/real/real04/0070.png (deflated 6%)
#   adding: dataset/real/real04/0071.png (deflated 6%)
#   adding: dataset/real/real04/0005.png (deflated 5%)
#   adding: dataset/real/real04/0000.png (deflated 8%)
#   adding: dataset/real/real04/0001.png (deflated 7%)
#   adding: dataset/real/real04/0002.png (deflated 5%)
#   adding: dataset/real/real04/0067.png (deflated 6%)
#   adding: dataset/real/real04/0078.png (deflated 7%)
#   adding: dataset/real/real04/0004.png (deflated 4%)
#   adding: dataset/real/real04/0076.png (deflated 7%)
#   adding: dataset/real/real04/0080.png (deflated 6%)
#   adding: dataset/real/real04/0081.png (deflated 7%)
#   adding: dataset/real/real04/0075.png (deflated 7%)
#   adding: dataset/real/real04/0077.png (deflated 8%)
#   adding: dataset/real/real04/0012.png (deflated 5%)
#   adding: dataset/real/real04/0010.png (deflated 4%)
#   adding: dataset/real/real04/0008.png (deflated 5%)
#   adding: dataset/real/real04/0009.png (deflated 4%)
#   adding: dataset/real/real04/0006.png (deflated 4%)
#   adding: dataset/real/real04/0007.png (deflated 5%)
#   adding: dataset/real/real04/0019.png (deflated 5%)
#   adding: dataset/real/real04/0017.png (deflated 5%)
#   adding: dataset/real/real04/0018.png (deflated 5%)
#   adding: dataset/real/real04/0016.png (deflated 5%)
#   adding: dataset/real/real04/0015.png (deflated 5%)
#   adding: dataset/real/real04/0014.png (deflated 5%)
#   adding: dataset/real/real04/0013.png (deflated 5%)
#   adding: dataset/real/real04/0011.png (deflated 4%)
#   adding: dataset/real/real04/0094.png (deflated 5%)
#   adding: dataset/real/real04/0093.png (deflated 5%)
#   adding: dataset/real/real04/0040.png (deflated 5%)
#   adding: dataset/real/real04/0041.png (deflated 5%)
#   adding: dataset/real/real04/0042.png (deflated 5%)
#   adding: dataset/real/real04/0043.png (deflated 5%)
#   adding: dataset/real/real04/0030.png (deflated 5%)
#   adding: dataset/real/real04/0022.png (deflated 5%)
#   adding: dataset/real/real04/0023.png (deflated 5%)
#   adding: dataset/real/real04/0028.png (deflated 5%)
#   adding: dataset/real/real04/0021.png (deflated 6%)
#   adding: dataset/real/real04/0020.png (deflated 6%)
#   adding: dataset/real/real04/0051.png (deflated 5%)
#   adding: dataset/real/real04/0050.png (deflated 5%)
#   adding: dataset/real/real04/0052.png (deflated 5%)
#   adding: dataset/real/real04/0037.png (deflated 4%)
#   adding: dataset/real/real04/0038.png (deflated 5%)
#   adding: dataset/real/real04/0039.png (deflated 5%)
#   adding: dataset/real/real04/0044.png (deflated 5%)
#   adding: dataset/real/real04/0045.png (deflated 5%)
#   adding: dataset/real/real04/0046.png (deflated 5%)
#   adding: dataset/real/real04/0047.png (deflated 5%)
